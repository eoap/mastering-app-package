# %% [markdown]
# # Run the otsu step
#
# This notebook is linked to https://eoap.github.io/mastering-app-package/python-env/otsu/

# %% [markdown]
# ## Setup the environment
#
# Create a folder for running the steps:

# %%
export WORKSPACE=/workspace/mastering-app-package
export RUNTIME=${WORKSPACE}/runs
mkdir -p ${RUNTIME}
cd ${RUNTIME}

# %% [markdown]
# ## Create the Hatch environment
#
# Hatch installs the package and its dependencies from `pyproject.toml`. Activate the environment before running the tool in the output directory.

# %%
cd "${WORKSPACE}/water-bodies/command-line-tools/otsu"
hatch env create default
source "$(hatch env find default)/bin/activate"
cd "${RUNTIME}"

# %%
which python

# %%
which pip

# %% [markdown]
# Check that the installed command is available:

# %%
command -v otsu

# %%
python -c "import rasterio; print(rasterio.__version__)"

# %% [markdown]
# ## Run the otsu application
#
# First dump the help:

# %%
otsu --help

# %%
otsu \
    --raster norm_diff.tif

# %% [markdown]
# List the outputs:

# %%
tree ${RUNTIME}

# %% [markdown]
# ## Leave the environment
#
# Deactivate the shell environment; keep the outputs for the next step.

# %%
deactivate
